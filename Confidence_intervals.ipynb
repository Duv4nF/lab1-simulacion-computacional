# %% [markdown]
# # Confidence intervals

# %%
import numpy as np
from scipy import stats
from IPython.display import display, Markdown

# %%
#M = [63.2, 69.7, 67.3, 64.8, 72]
M = [0.55, 0.4, 0.3, 0.2, 0.15, 0.25, 0.3, 0.6, 0.5, 0.5]

print(M)
reps = len(M)

print("Rep.\tAvg Time")
for i in range(0, len(M)):
    print("%d\t%g" % (i+1,M[i]), sep=' ', end='\n')
# Out:
# [0.55, 0.4, 0.3, 0.2, 0.15, 0.25, 0.3, 0.6, 0.5, 0.5]
# Rep.	Avg Time
# 1	0.55
# 2	0.4
# 3	0.3
# 4	0.2
# 5	0.15
# 6	0.25
# 7	0.3
# 8	0.6
# 9	0.5
# 10	0.5

# %%
alpha = 0.05
confidence = (1-alpha)*100

mean = np.mean(M)
var = np.var(M,ddof=1)
desv = np.sqrt(var)

tval = stats.t.ppf(1-(alpha/2), reps-1)
hval = tval*(desv/np.sqrt(reps))

display(Markdown(
   rf"""
${confidence}\%$ confidence

$\bar{{X}} = {mean}$

$S = {desv}$

$t_{{n-1,1-\frac{{\alpha}}{2}}} = t_{{{reps-1},{1-alpha/2}}} ={tval}$

$h = {hval}$

Intervalo de confianza : $C.I. = (\bar{{X}}-h , \bar{{X}} + h) = ({mean-hval},{mean+hval})$

"""))
# Out:
# $95.0\%$ confidence
#
# $\bar{X} = 0.375$
#
# $S = 0.15679073101855648$
#
# $t_{n-1,1-\frac{\alpha}2} = t_{9,0.975} =2.2621571628540993$
#
# $h = 0.11216133222908461$
#
# Intervalo de confianza : $C.I. = (\bar{X}-h , \bar{X} + h) = (0.26283866777091536,0.48716133222908464)$
